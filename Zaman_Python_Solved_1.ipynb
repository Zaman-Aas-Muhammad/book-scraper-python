# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaman-Aas-Muhammad/book-scraper-python/blob/main/Zaman_Python_Solved_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Programming – Solved Code Examples**Name:** Muhammad Zaman  **Class:** BSCS – 3rd Semester (Section 3B)  **Subject:** Programming Fundamentals (Python)  **University:** Lahore Leads University, LahoreRun each cell (Shift+Enter) to see the verified output.

# %% [markdown]
# ## 1. Operators in Python

# %%
# Arithmeticx, y = 10, 3print("x + y", x + y)print("x - y", x - y)print("x * y", x * y)print("x / y", x / y)print("x % y", x % y)print("x ** y", x ** y)print("x // y", x // y)# Assignmentx = 5x += 3print("x after x+=3", x)# Comparisonx, y = 5, 3print("x == y", x == y)print("x != y", x != y)print("x > y", x > y)print("x < y", x < y)# Logicalx = 7print("x < 5 and x < 10", x < 5 and x < 10)print("x < 5 or x < 10", x < 5 or x < 10)print("not(x < 5 and x < 10)", not (x < 5 and x < 10))# Identitya = ["apple", "banana"]b = ["apple", "banana"]c = aprint("a is b", a is b)print("a is c", a is c)# Membershipfruits = ["apple", "banana", "cherry", "orange"]print('"banana" in fruits', "banana" in fruits)print('"grape" in fruits', "grape" in fruits)# Bitwisea, b = 10, 5print("a & b", a & b)print("a | b", a | b)print("a ^ b", a ^ b)print("~a", ~a)print("a << 2", a << 2)print("a >> 2", a >> 2)# Precedenceprint("(6+3)-(6+3)", (6 + 3) - (6 + 3))print("100 + 5*3", 100 + 5 * 3)print("5+4-7+3", 5 + 4 - 7 + 3)

# %% [markdown]
# ## 2. List in Python

# %%
thislist = ["apple", "banana", "cherry"]print("thislist", thislist)print("len(thislist)", len(thislist))print("thislist[1]", thislist[1])print("thislist[-1]", thislist[-1])thislist2 = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]print("thislist2[2:5]", thislist2[2:5])print("thislist2[:4]", thislist2[:4])print("thislist2[2:]", thislist2[2:])print("thislist2[-4:-1]", thislist2[-4:-1])thislist3 = ["apple", "banana", "cherry"]print('"apple" in thislist3', "apple" in thislist3)thislist3[1] = "blackcurrant"print("after thislist3[1]='blackcurrant'", thislist3)thislist4 = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]thislist4[1:3] = ["blackcurrant", "watermelon"]print("after range replace", thislist4)thislist5 = ["apple", "banana", "cherry"]thislist5.insert(2, "watermelon")print("after insert(2,'watermelon')", thislist5)thislist6 = ["apple", "banana", "cherry"]thislist6.append("orange")print("after append('orange')", thislist6)thislist7 = ["apple", "banana", "cherry"]tropical = ["mango", "pineapple", "papaya"]thislist7.extend(tropical)print("after extend(tropical)", thislist7)thislist8 = ["apple", "banana", "cherry"]thislist8.remove("banana")print("after remove('banana')", thislist8)thislist9 = ["apple", "banana", "cherry"]thislist9.pop(1)print("after pop(1)", thislist9)thislist10 = ["apple", "banana", "cherry"]del thislist10[0]print("after del thislist10[0]", thislist10)thislist11 = ["apple", "banana", "cherry"]thislist11.clear()print("after clear()", thislist11)fruits = ["apple", "banana", "cherry", "kiwi", "mango"]newlist = [x for x in fruits if "a" in x]print("list comprehension (has 'a')", newlist)newlist2 = [x.upper() for x in fruits]print("list comprehension upper", newlist2)thislist12 = ["orange", "mango", "kiwi", "pineapple", "banana"]thislist12.sort()print("after sort()", thislist12)thislist13 = [100, 50, 65, 82, 23]thislist13.sort(reverse=True)print("after sort(reverse=True)", thislist13)thislist14 = ["banana", "Orange", "Kiwi", "cherry"]thislist14.sort(key=str.lower)print("case-insensitive sort", thislist14)thislist15 = ["banana", "Orange", "Kiwi", "cherry"]thislist15.reverse()print("after reverse()", thislist15)list1 = ["a", "b", "c"]list2 = [1, 2, 3]list3 = list1 + list2print("list1 + list2", list3)

# %% [markdown]
# ## 3. Tuple in Python
